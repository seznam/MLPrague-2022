# %% [markdown]
# # Workshop on Recommendation systems and user representations
#
# ### Motivation
# Following tutorial tries to illustrate typical production setting in a company which provides multiple types of content and have various recommender systems inplace.
#
# Single recommender system is typically focused only on the part of the content portfolio in which it operates and will not have access to full user interaction sequence - which is typically due to RAM/CPU/storage/logistics restrictions.
#
# As an example we can take look at the [seznam.cz](https://www.seznam.cz) page on which we can find recommended arcticles for website novinky.cz.
#
# At the same time user might have visited different website in Seznam's ecosystem e.g. [zbozi.cz](https://www.zbozi.cz) which has its own set of recommender systems which serve various purposes and implicitly do not model user behavior in Seznam's ecosystem.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In order to achieve efficient personalization accross many models one needs to create efficient user representation which might also alleviate [cold-start problem](https://en.wikipedia.org/wiki/Cold_start_(recommender_systems)).
#
#
# Following tutorial tries to:
#  - **ilustrate various techniques which might yield such efficient user representation**
#  - **demonstrate how such representation might be used in ranking model which is an essential part of recommender system**

# %% [markdown]
# ### Agenda
#
# 1. At first we will download and prepare [MIND dataset](https://msnews.github.io/) by running notebook [001-prepare-dataset](https://colab.research.google.com/github/seznam/MLPrague-2022/blob/master/notebooks/001_prepare_dataset.ipynb)
# 2. At the next phase we will investigate attributes of newly created dataset by running notebook [002-explorative-data-analysis](https://colab.research.google.com/github/seznam/MLPrague-2022/blob/master/notebooks/002_exploratory_data_analysis.ipynb)
# 3. User representation will be computed in notebook [003-user-representation-embedding](https://colab.research.google.com/github/seznam/MLPrague-2022/blob/master/notebooks/003_user_representation_embedding.ipynb)
# 4. At the end we will train [DCN model](https://www.tensorflow.org/recommenders/examples/dcn) on created user representation by running notebook [004-train-dcn-model-user-representation](https://colab.research.google.com/github/seznam/MLPrague-2022/blob/master/notebooks/004_train_dcn_model_user_representation.ipynb)
#
#
# ### Requirements
# Tutorial will be executed in [google colab](https://colab.research.google.com/) which means that users need:
# * to have google account
# * have enough free space on google drive
# * web browser
#
# ### Solutions
#
# During the tutorial, you will go through several tasks.
# Here, we provide solutions to those tasks so that you can fix your code if there is any problem or you can compare your solution to the one provided by us.
# * Solutions for [004-train-dcn-model-user-representation](https://colab.research.google.com/github/seznam/MLPrague-2022/blob/master/notebooks/solution/004_train_dcn_model_user_representation.ipynb)
#
# ### Technical notes
# Notebooks are linearly dependent and store intermediate results on google disk therefore at the beggining of every notebook user will be asked to grant access to google disk:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Neural network training can be speed up by using GPU or TPU accelerator.
# Tutorial on enabling GPU can be found in [here](https://www.tutorialspoint.com/google_colab/google_colab_using_free_gpu.htm)

# %% [markdown]
# ### Feedback
# We'd love to hear your [feedback](https://forms.gle/G9QDmXyZJJyrbnzt9)!

# %% [markdown]
# ### Presentation of the theoretical part
# https://raw.githubusercontent.com/seznam/MLPrague-2022/master/presentation/MLPrague2022_final.pdf
